# %%
class Bags:
    name = "Lakshay"

    def details(self):
        print("This is something.")

# Creating an object
# For creation of an object go outside the class to create
# a varibale and initialize it using Class().

# A class can have multiple objects/instances/children.

reebok = Bags()      
campus = Bags()

# The object has all the powers of a class therefore a class
# object can access attributes and methods of a class.

print(reebok.name)
print(campus.name)

# Acessing methods
reebok.details()
# Out:
# Lakshay
# Lakshay
# This is something.
