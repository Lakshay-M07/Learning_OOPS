# %%
# Imperative Approach
# Basically using only variables to solve a problem

a = 10
b = 20

print (a+b)
# Out:
# 30

# %%
# Functional Approach
# Using functions to solve a problem

def addition(x , y):
    print(x+y)

addition(30,300)
addition(20,40)
# Out:
# 330
# 60

# %%
# Object Oriented Approach
# Using classes and objects to solve a problem
